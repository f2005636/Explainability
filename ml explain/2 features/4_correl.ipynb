# %% [markdown]
# # 1. import libraries

# %%
import warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
warnings.filterwarnings("ignore")
# %matplotlib inline
plt.style.use('seaborn-white')
plt.rcParams['figure.figsize'] = 15,5

# %% [markdown]
# ---
# # 2. import dataset

# %%
df = pd.read_csv('master.csv')
df = df.drop_duplicates()
df.shape
# Out:
# (522, 14)

# %%
df['Y'].value_counts()
# Out:
# 1    276
# 0    246
# Name: Y, dtype: int64

# %% [markdown]
# ---
# # 3. correl - 1st iteration

# %%
df = df.drop('Y',axis=1)

# %%
sns.heatmap(df.corr(),cmap="Greens",annot = True);

# %% [markdown]
# ---
# # 4. correl - 2nd iteration

# %%
df = df.drop(['MaritalStatus','EmploymentStatus','OccupationArea','UseOfLoan'],axis=1)

# %%
sns.heatmap(df.corr(),cmap="Greens",annot = True);

# %% [markdown]
# ---
# # 5. export dataset

# %%
df = pd.read_csv('master.csv')
df = df.drop_duplicates()
df = df.drop(['MaritalStatus','EmploymentStatus','OccupationArea','UseOfLoan'], axis=1)

# %%
df.to_csv('temp.csv', index=False)
df.shape
# Out:
# (522, 10)
