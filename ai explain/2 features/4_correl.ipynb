# %% [markdown]
# # 1. import libraries

# %%
import warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
warnings.filterwarnings("ignore")
# %matplotlib inline
plt.style.use('seaborn-white')
plt.rcParams['figure.figsize'] = 15,5

# %% [markdown]
# ---
# # 2. import dataset

# %%
df = pd.read_csv('../0 data/master.csv')
df = df.drop_duplicates()
df.shape
# Out:
# (66034, 6)

# %%
df['Y'].value_counts()
# Out:
# 0    59710
# 1     6324
# Name: Y, dtype: int64

# %% [markdown]
# ---
# # 3. correl

# %%
df = df.drop(['id','Y'],axis=1)
sns.heatmap(df.corr().abs(),cmap="Greens",annot = True);
